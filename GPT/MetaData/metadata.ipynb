# %% [markdown]
# ### NB: Kjøringen av denen filen vil resulatere i en yaml fil på underkant av 4 millioner linjer, med en størrelse på ca. 103 mb. Maks limit på standard git er 100 mb.  Tar ca. 280 minutter å kjøre koden.

# %%
import json
import requests

# %%
def hent_data(url):
    # Sender en GET-forespørsel til URL-en
    respons = requests.get(url)

    # Sjekker om forespørselen var vellykket
    if respons.status_code == 200:
        # Returnerer JSON-innholdet i responsen
        return respons.json()
    else:
        # Returnerer en feilmelding hvis forespørselen mislykkes
        return f"Feil i forespørsel: Statuskode {respons.status_code}"

# URL til API-endepunktet
url = "https://data.qa.ssb.no/pxapi2-beta/api/v2/tables?pageSize=100000"

# Kaller funksjonen og skriver ut resultatet
result = hent_data(url)

# %%
# Parse the data
data = result['tables']

# %%
data
# Out:
# [{'type': 'Table',
#   'id': '13760',
#   'label': '13760: Arbeidsstyrken, sysselsatte, arbeidsledige og utførte ukeverk, etter kjønn, alder og type justering. Bruddjusterte tall 2006M01-2023M04',
#   'description': '',
#   'updated': '2023-04-26T06:00:00Z',
#   'firstPeriod': '2006M01',
#   'lastPeriod': '2023M04',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'alder',
#    'type justering',
#    'statistikkvariabel',
#    'måned'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13760?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13760/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13760/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07458',
#   'label': '07458: Sysselsetting, arbeidsledighet og utførte ukeverk, etter alder. Brudd- og sesongjustert, kvartalstall 1997K1-2023K1',
#   'description': '',
#   'updated': '2023-04-26T06:00:00Z',
#   'firstPeriod': '1997K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['alder', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07458?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07458/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07458/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13618',
#   'label': '13618: Personer, etter arbeidsstyrkestatus, kjønn og alder. Bruddjusterte tall 2009-2022',
#   'description': '',
#   'updated': '2023-04-11T06:00:00Z',
#   'firstPeriod': '2009',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['arbeidsstyrkestatus',
#    'kjønn',
#    'alder',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13618?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13618/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13618/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13619',
#   'label': '13619: Personer, etter arbeidsstyrkestatus, kjønn og alder. Bruddjusterte tall 2009K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2009K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['arbeidsstyrkestatus',
#    'kjønn',
#    'alder',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13619?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13619/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13619/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '05110',
#   'label': '05110: Personer, etter arbeidsstyrkestatus, kjønn og alder 1988K2-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '1988K2',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['arbeidsstyrkestatus',
#    'kjønn',
#    'alder',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/05110?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/05110/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/05110/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '05111',
#   'label': '05111: Personer, etter arbeidsstyrkestatus, kjønn og alder 1972-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '1972',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['arbeidsstyrkestatus',
#    'kjønn',
#    'alder',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/05111?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/05111/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/05111/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13497',
#   'label': '13497: Personer, etter arbeidsstyrkestatus, kjønn og landsdel 2021K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2021K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['arbeidsstyrkestatus',
#    'kjønn',
#    'landsdel',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13497?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13497/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13497/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13498',
#   'label': '13498: Personer, etter arbeidsstyrkestatus, kjønn og landsdel 2021-2022',
#   'description': '',
#   'updated': '2023-04-26T06:00:00Z',
#   'firstPeriod': '2021',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['arbeidsstyrkestatus',
#    'kjønn',
#    'landsdel',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13498?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13498/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13498/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '03777',
#   'label': '03777: Personer i arbeidsstyrken, etter kjønn og alder 1972K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '1972K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['alder', 'kjønn', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03777?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03777/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03777/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '03780',
#   'label': '03780: Personer i arbeidsstyrken, etter kjønn og alder 1972-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '1972',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['alder', 'kjønn', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03780?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03780/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03780/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11433',
#   'label': '11433: Strømmer mellom arbeidsstyrkestatuser, etter kjønn 2006K2-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2006K2',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['endring i arbeidsstyrkestatus',
#    'kjønn',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11433?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11433/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11433/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13784',
#   'label': '13784: Personer, etter arbeidsstyrkestatus, kjønn, alder og utdanningsnivå 2021K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2021K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['arbeidsstyrkestatus',
#    'kjønn',
#    'alder',
#    'utdanningsnivå',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13784?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13784/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13784/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13785',
#   'label': '13785: Personer, etter arbeidsstyrkestatus, kjønn, alder og utdanningsnivå 2021-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '2021',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['arbeidsstyrkestatus',
#    'kjønn',
#    'alder',
#    'utdanningsnivå',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13785?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13785/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13785/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08518',
#   'label': '08518: Arbeidsledige, etter kjønn og alder 1972K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '1972K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn', 'alder', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08518?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08518/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08518/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08517',
#   'label': '08517: Arbeidsledige, etter kjønn og alder 1972-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '1972',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn', 'alder', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08517?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08517/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08517/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04552',
#   'label': '04552: Arbeidsledige, etter kjønn og søkingens varighet (1 000 personer) 1996K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '1996K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'søkingens varighet',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04552?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04552/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04552/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04553',
#   'label': '04553: Arbeidsledige, etter kjønn og søkingens varighet (1 000 personer) 1996-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '1996',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn', 'søkingens varighet', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04553?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04553/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04553/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13891',
#   'label': '13891: Arbeidsledige, etter kjønn, hovedsakelig virksomhet og alder 2021K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2021K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'hovedsakelig virksomhet',
#    'alder',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13891?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13891/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13891/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13892',
#   'label': '13892: Arbeidsledige, etter kjønn, hovedsakelig virksomhet og alder 2021-2022',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2021',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'hovedsakelig virksomhet',
#    'alder',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13892?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13892/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13892/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04554',
#   'label': '04554: Undersysselsatte og arbeidsledige, etter ønsket arbeidstid per uke. Tilbud av ukeverk (a 37,5 timer) 1996K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '1996K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['ønsket arbeidstid',
#    'undersysselsatte og arbeidsledige',
#    'kjønn',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04554?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04554/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04554/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04555',
#   'label': '04555: Undersysselsatte og arbeidsledige, etter ønsket arbeidstid per uke. Tilbud av ukeverk (a 37,5 timer) 1996-2022',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '1996',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['ønsket arbeidstid',
#    'undersysselsatte og arbeidsledige',
#    'kjønn',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04555?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04555/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04555/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13534',
#   'label': '13534: Den utvidede arbeidsstyrken, etter kjønn, arbeidsmarkedsstatus og alder 2021K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2021K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'arbeidsmarkedsstatus',
#    'alder',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13534?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13534/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13534/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13535',
#   'label': '13535: Den utvidede arbeidsstyrken, etter kjønn, arbeidsmarkedsstatus og alder 2021-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '2021',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'arbeidsmarkedsstatus',
#    'alder',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13535?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13535/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13535/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13583',
#   'label': '13583: Personer utenfor arbeidsstyrken, etter kjønn, alder og hovedsakelig virksomhet 2021K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2021K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'alder',
#    'hovedsakelig virksomhet',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13583?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13583/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13583/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13584',
#   'label': '13584: Personer utenfor arbeidsstyrken, etter kjønn, alder og hovedsakelig virksomhet 2021-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '2021',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'alder',
#    'hovedsakelig virksomhet',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13584?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13584/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13584/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '03778',
#   'label': '03778: Sysselsatte, etter kjønn og alder 1996K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '1996K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['alder', 'kjønn', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03778?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03778/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03778/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '03781',
#   'label': '03781: Sysselsatte, etter kjønn og alder 1972-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '1972',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['alder', 'kjønn', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03781?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03781/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03781/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07972',
#   'label': '07972: Sysselsatte, etter kjønn, alder og næring (SN2007) (1 000 personer) 2008K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2008K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'næring (SN2007)',
#    'alder',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07972?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07972/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07972/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07971',
#   'label': '07971: Sysselsatte, etter kjønn, alder og næring (SN2007) (1 000 personer) 2008-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '2008',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'næring (SN2007)',
#    'alder',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07971?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07971/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07971/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11154',
#   'label': '11154: Sysselsatte, etter kjønn og næring (SN2007) (1 000 personer) 2008K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2008K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'næring (SN2007)',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11154?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11154/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11154/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11153',
#   'label': '11153: Sysselsatte, etter kjønn og næring (SN2007) (1 000 personer) 2008-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '2008',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn', 'næring (SN2007)', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11153?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11153/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11153/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11131',
#   'label': '11131: Sysselsatte, etter kjønn, næring (SN2007) og yrkesstatus (1 000 personer) (midlertidig ikke oppdatert) 2008-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2008',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'næring (SN2007)',
#    'yrkesstatus',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11131?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11131/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11131/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08416',
#   'label': '08416: Sysselsatte, etter kjønn, næring (SN2007) og utdanningsnivå (1 000 personer) (midlertidig ikke oppdatert) 2008K1-2020K4',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2008K1',
#   'lastPeriod': '2020K4',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'næring',
#    'utdanningsnivå',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08416?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08416/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08416/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08415',
#   'label': '08415: Sysselsatte, etter kjønn, næring (SN2007) og utdanningsnivå (1 000 personer) (midlertidig ikke oppdatert) 2008-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2008',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'næring',
#    'utdanningsnivå',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08415?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08415/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08415/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09789',
#   'label': '09789: Sysselsatte, etter næring (SN2007) og yrke. Årsgjennomsnitt (1 000 personer) 2011-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '2011',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['næring (SN2007)', 'yrke', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09789?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09789/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09789/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09788',
#   'label': '09788: Sysselsatte, etter kjønn og yrke. Årsgjennomsnitt 2011-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '2011',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn', 'yrke', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09788?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09788/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09788/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09792',
#   'label': '09792: Sysselsatte, etter kjønn og yrker med minst 5000 sysselsatte (4-siffernivå) . Årsgjennomsnitt (1 000 personer) 2011-2022',
#   'description': '',
#   'updated': '2023-04-19T06:00:00Z',
#   'firstPeriod': '2011',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn', 'yrke', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09792?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09792/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09792/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09793',
#   'label': '09793: Sysselsatte, etter kjønn, alder og yrke (2-siffernivå). Årsgjennomsnitt (1 000 personer) 2011-2022',
#   'description': '',
#   'updated': '2023-04-19T06:00:00Z',
#   'firstPeriod': '2011',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn', 'alder', 'yrke', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09793?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09793/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09793/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09791',
#   'label': '09791: Sysselsatte, etter kjønn, yrke og sektor. Årsgjennomsnitt (1 000 personer) (midlertidig ikke oppdatert) 2011-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2011',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['kjønn', 'yrke', 'sektor', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09791?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09791/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09791/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13564',
#   'label': '13564: Sysselsatte (1 000 personer), etter kjønn, alder, yrkesstatus og heltid/deltid 2021-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '2021',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'alder',
#    'yrkesstatus',
#    'vanlig arbeidstid (heltid/deltid)',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13564?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13564/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13564/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08420',
#   'label': '08420: Sysselsatte, etter kjønn, heltid/deltid og utdanningsnivå (1 000 personer) 2006K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2006K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'heltid/deltid',
#    'utdanningsnivå',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08420?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08420/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08420/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08417',
#   'label': '08417: Sysselsatte, etter kjønn, heltid/deltid og utdanningsnivå (1 000 personer) 2006-2022',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2006',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'heltid/deltid',
#    'utdanningsnivå',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08417?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08417/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08417/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07202',
#   'label': '07202: Sysselsatte, etter kjønn, næring (SN2007) og avtalt/vanlig arbeidstid per uke (1 000 personer)  (midlertidig ikke oppdatert) 2008K1-2020K4',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2008K1',
#   'lastPeriod': '2020K4',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'næring (SN2007)',
#    'avtalt arbeidstid',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07202?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07202/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07202/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07203',
#   'label': '07203: Sysselsatte, etter kjønn, næring (SN2007) og avtalt/vanlig arbeidstid per uke (1 000 personer) (midlertidig ikke oppdatert) 2008-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2008',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'næring (SN2007)',
#    'avtalt arbeidstid',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07203?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07203/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07203/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09790',
#   'label': '09790: Sysselsatte, etter kjønn, yrke og avtalt/vanlig arbeidstid. Årsgjennomsnitt (midlertidig ikke oppdatert) 2011-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2011',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['kjønn', 'yrke', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09790?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09790/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09790/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07856',
#   'label': '07856: Sysselsattes utførte ukeverk (a 37,5 timer) og faktisk arbeidstid per uke, etter kjønn og næring (SN2007) 2008K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2008K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'næring (SN2007)',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07856?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07856/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07856/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07855',
#   'label': '07855: Sysselsattes utførte ukeverk (a 37,5 timer) og faktisk arbeidstid per uke, etter kjønn og næring (SN2007) 2008-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '2008',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn', 'næring (SN2007)', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07855?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07855/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07855/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04542',
#   'label': '04542: Sysselsatte i alt og i arbeid, utførte ukeverk (a 37,5 timer) og faktisk arbeidstid, etter kjønn og yrkesstatus 1996K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '1996K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn', 'yrkesstatus', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04542?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04542/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04542/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04544',
#   'label': '04544: Sysselsatte i alt og i arbeid, utførte ukeverk (a 37,5 timer) og faktisk arbeidstid, etter kjønn og yrkesstatus 1996-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '1996',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn', 'yrkesstatus', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04544?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04544/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04544/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04545',
#   'label': '04545: Sysselsatte midlertidig fraværende hele uka, etter kjønn og  årsak til fravær 1996K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '1996K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['årsak til fravær',
#    'kjønn',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04545?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04545/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04545/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04547',
#   'label': '04547: Sysselsatte midlertidig fraværende hele uka, etter kjønn og årsak til fravær 1996-2022',
#   'description': '',
#   'updated': '2023-01-26T07:00:00Z',
#   'firstPeriod': '1996',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['årsak til fravær', 'kjønn', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04547?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04547/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04547/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13782',
#   'label': '13782: Sysselsatte midlertidig fraværende hele/deler av uka, etter kjønn, alder og årsak til fravær 2021K1-2023K1',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2021K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'alder',
#    'årsak til fravær',
#    'lengde på fravær',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13782?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13782/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13782/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '13783',
#   'label': '13783: Sysselsatte midlertidig fraværende hele/deler av uka, etter kjønn, alder og årsak til fravær 2021-2022',
#   'description': '',
#   'updated': '2023-05-09T06:00:00Z',
#   'firstPeriod': '2021',
#   'lastPeriod': '2022',
#   'category': 'public',
#   'variableNames': ['kjønn',
#    'alder',
#    'årsak til fravær',
#    'lengde på fravær',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13783?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13783/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/13783/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11424',
#   'label': '11424: Heltidsansatte med overtid og overtidsukeverk, etter kjønn og alder. Årsgjennomsnitt (midlertidig ikke oppdatert) 2006-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2006',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['kjønn', 'alder', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11424?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11424/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11424/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11430',
#   'label': '11430: Heltidsansatte med overtid og overtidsukeverk, etter kjønn og utdanningsnivå. Årsgjennomsnitt (midlertidig ikke oppdatert) 2006-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2006',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['kjønn', 'utdanningsnivå', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11430?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11430/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11430/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11432',
#   'label': '11432: Heltidsansatte med overtid og overtidsukeverk (a 37,5 timer), etter yrke. Årsgjennomsnitt (midlertidig ikke oppdatert) 2011-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2011',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['yrke', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11432?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11432/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11432/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11429',
#   'label': '11429: Heltidsansatte med overtid og overtidsukeverk, etter næring (SN2007). Årsgjennomsnitt (midlertidig ikke oppdatert) 2008-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2008',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['næring (SN2007)', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11429?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11429/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11429/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11517',
#   'label': '11517: Heltidsansatte med overtid og overtidsukeverk, etter utvalgte næringer (SN2007) (midlertidig ikke oppdatert) 2008K1-2020K4',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2008K1',
#   'lastPeriod': '2020K4',
#   'category': 'public',
#   'variableNames': ['næring (SN2007)', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11517?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11517/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11517/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11431',
#   'label': '11431: Ukeverk (a 37,5 timer) overtid blant heltidsansatte, etter kompensasjonsmåte og utvalgte næringer (SN2007). Årsgjennomsnitt (1 000 ukeverk) (midlertidig ikke oppdatert) 2008-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2008',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['kompensasjonsmåte',
#    'næring (SN2007)',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11431?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11431/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11431/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09731',
#   'label': '09731: Ansatte i hovedarbeidsforhold, etter arbeidstidsordning, kjønn og alder (midlertidig ikke oppdatert) 2001-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2001',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['arbeidstidsordning',
#    'kjønn',
#    'alder',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09731?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09731/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09731/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09734',
#   'label': '09734: Ansatte i hovedarbeidsforhold, etter arbeidstidsordning, kjønn og næring (SN2007) (midlertidig ikke oppdatert) 2008-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2008',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['arbeidstidsordning',
#    'kjønn',
#    'næring (SN2007)',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09734?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09734/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09734/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09733',
#   'label': '09733: Ansatte i hovedarbeidsforhold, etter arbeidstidsordning, kjønn og ansettelsesform (midlertidig ikke oppdatert) 2001-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2001',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['arbeidstidsordning',
#    'kjønn',
#    'ansettelsesform',
#    'statistikkvariabel',
#    'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09733?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09733/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09733/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09882',
#   'label': '09882: Ansatte i hovedarbeidsforhold og eventuelt i biarbeidsforhold, etter arbeidstidsordning, kjønn og alder (midlertidig ikke oppdatert) 2001-2020',
#   'description': '',
#   'updated': '2021-01-28T07:00:00Z',
#   'firstPeriod': '2001',
#   'lastPeriod': '2020',
#   'category': 'public',
#   'variableNames': ['arbeidstidsordning',
# ...
#   'id': '03958',
#   'label': '03958: Finansinstitusjoner. Balanse, etter finansobjekt (mill. kr) (avslutta serie) 1997K1-2011K4',
#   'description': '',
#   'updated': '2012-02-28T09:00:00Z',
#   'firstPeriod': '1997K1',
#   'lastPeriod': '2011K4',
#   'category': 'public',
#   'variableNames': ['finansinstitusjonstype',
#    'finansobjekt',
#    'statistikkvariabel',
#    'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03958?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03958/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/03958/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04479',
#   'label': '04479: Finansielle holdingselskaper. Balanse (mill. kr) 1994-2021',
#   'description': '',
#   'updated': '2022-06-22T06:00:00Z',
#   'firstPeriod': '1994',
#   'lastPeriod': '2021',
#   'category': 'public',
#   'variableNames': ['balansepost', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04479?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04479/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04479/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04480',
#   'label': '04480: Finansielle holdingselskaper. Resultatregnskap (mill. kr) 1994-2021',
#   'description': '',
#   'updated': '2022-06-22T06:00:00Z',
#   'firstPeriod': '1994',
#   'lastPeriod': '2021',
#   'category': 'public',
#   'variableNames': ['resultatpost', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04480?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04480/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04480/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '05164',
#   'label': '05164: Finansielle holdingselskaper. Verdipapirer og disponert utlån (mill. kr) 1996-2021',
#   'description': '',
#   'updated': '2022-06-22T06:00:00Z',
#   'firstPeriod': '1996',
#   'lastPeriod': '2021',
#   'category': 'public',
#   'variableNames': ['sektor', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/05164?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/05164/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/05164/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08489',
#   'label': '08489: Livsforsikringsselskaper. Balanse, etter finansobjekt (mill. kr) 2005-2021',
#   'description': '',
#   'updated': '2023-01-20T07:00:00Z',
#   'firstPeriod': '2005',
#   'lastPeriod': '2021',
#   'category': 'public',
#   'variableNames': ['finansobjekt', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08489?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08489/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08489/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08490',
#   'label': '08490: Livsforsikringsselskaper. Resultatregnskap (mill. kr) 2005-2021',
#   'description': '',
#   'updated': '2023-01-20T07:00:00Z',
#   'firstPeriod': '2005',
#   'lastPeriod': '2021',
#   'category': 'public',
#   'variableNames': ['resultatpost', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08490?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08490/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08490/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08491',
#   'label': '08491: Livs- og skadeforsikringsselskaper. Verdipapirer og utlån (mill. kr) 2005-2021',
#   'description': '',
#   'updated': '2023-01-20T07:00:00Z',
#   'firstPeriod': '2005',
#   'lastPeriod': '2021',
#   'category': 'public',
#   'variableNames': ['selskapstype', 'sektor', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08491?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08491/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08491/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08492',
#   'label': '08492: Skadeforsikringsselskaper. Balanse, etter finansobjekt (mill. kr) 2005-2021',
#   'description': '',
#   'updated': '2023-01-20T07:00:00Z',
#   'firstPeriod': '2005',
#   'lastPeriod': '2021',
#   'category': 'public',
#   'variableNames': ['finansobjekt', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08492?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08492/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08492/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '08493',
#   'label': '08493: Skadeforsikringsselskaper. Resultatregnskap (mill. kr) 2005-2021',
#   'description': '',
#   'updated': '2023-01-20T07:00:00Z',
#   'firstPeriod': '2005',
#   'lastPeriod': '2021',
#   'category': 'public',
#   'variableNames': ['resultatpost', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08493?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08493/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/08493/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07693',
#   'label': '07693: Livsforsikring. Premier og erstatninger, etter bransje (mill. kr.) 1997-2021',
#   'description': '',
#   'updated': '2023-01-20T07:00:00Z',
#   'firstPeriod': '1997',
#   'lastPeriod': '2021',
#   'category': 'public',
#   'variableNames': ['bransje', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07693?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07693/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07693/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '11580',
#   'label': '11580: Skadeforsikring.  Premier og erstatninger, etter bransje (mill. kr) 2012-2021',
#   'description': '',
#   'updated': '2023-01-20T07:00:00Z',
#   'firstPeriod': '2012',
#   'lastPeriod': '2021',
#   'category': 'public',
#   'variableNames': ['bransje', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11580?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11580/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/11580/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07505',
#   'label': '07505: Livsforsikringsselskaper. Balanse, etter finansobjekt (mill. kr) 1997K1-2023K1',
#   'description': '',
#   'updated': '2023-02-28T07:00:00Z',
#   'firstPeriod': '1997K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['finansobjekt', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07505?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07505/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07505/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07506',
#   'label': '07506: Livsforsikringsselskaper. Resultatregnskap (mill. kr) 1997K1-2023K1',
#   'description': '',
#   'updated': '2023-02-28T07:00:00Z',
#   'firstPeriod': '1997K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['resultatpost', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07506?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07506/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07506/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '09583',
#   'label': '09583: Livs- og skadeforsikringsselskaper. Verdipapirer og utlån (mill. kr) 1997K1-2023K1',
#   'description': '',
#   'updated': '2023-02-28T07:00:00Z',
#   'firstPeriod': '1997K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['selskapstype', 'sektor', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09583?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09583/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/09583/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07507',
#   'label': '07507: Skadeforsikringsselskaper. Balanse, etter finansobjekt (mill. kr) 1997K4-2023K1',
#   'description': '',
#   'updated': '2023-03-01T07:00:00Z',
#   'firstPeriod': '1997K4',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['finansobjekt', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07507?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07507/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07507/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '07508',
#   'label': '07508: Skadeforsikringsselskaper. Resultatregnskap (mill. kr) 1997K1-2023K1',
#   'description': '',
#   'updated': '2023-02-28T07:00:00Z',
#   'firstPeriod': '1997K1',
#   'lastPeriod': '2023K1',
#   'category': 'public',
#   'variableNames': ['resultatpost', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07508?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07508/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/07508/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04183',
#   'label': '04183: Livsforsikringsselskaper. Balanse, etter finansobjekt (mill. kr) (avslutta serie) 1990-2008',
#   'description': '',
#   'updated': '2009-12-22T09:00:00Z',
#   'firstPeriod': '1990',
#   'lastPeriod': '2008',
#   'category': 'public',
#   'variableNames': ['finansobjekt', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04183?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04183/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04183/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04083',
#   'label': '04083: Livsforsikringsselskaper. Balanse, etter finansobjekt (mill. kr) (avslutta serie) 1997K4-2009K2',
#   'description': '',
#   'updated': '2009-09-14T08:00:00Z',
#   'firstPeriod': '1997K4',
#   'lastPeriod': '2009K2',
#   'category': 'public',
#   'variableNames': ['finansobjekt', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04083?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04083/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04083/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04184',
#   'label': '04184: Livsforsikringsselskaper. Resultatregnskap (mill. kr) (avslutta serie) 1995-2008',
#   'description': '',
#   'updated': '2009-12-22T09:00:00Z',
#   'firstPeriod': '1995',
#   'lastPeriod': '2008',
#   'category': 'public',
#   'variableNames': ['resultatpost', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04184?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04184/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04184/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04084',
#   'label': '04084: Livsforsikringsselskaper. Resultatregnskap (mill. kr) (avslutta serie) 1997K4-2009K2',
#   'description': '',
#   'updated': '2009-09-14T08:00:00Z',
#   'firstPeriod': '1997K4',
#   'lastPeriod': '2009K2',
#   'category': 'public',
#   'variableNames': ['resultatpost', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04084?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04084/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04084/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04187',
#   'label': '04187: Livs- og skadeforsikringsselskaper. Verdipapirer og utlån (mill. kr) (avslutta serie) 1995-2008',
#   'description': '',
#   'updated': '2009-12-22T09:00:00Z',
#   'firstPeriod': '1995',
#   'lastPeriod': '2008',
#   'category': 'public',
#   'variableNames': ['selskapstype', 'sektor', 'statistikkvariabel', 'år'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04187?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04187/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04187/data?lang=no'}]},
#  {'type': 'Table',
#   'id': '04087',
#   'label': '04087: Livs- og skadeforsikringsselskaper. Verdipapirer og utlån (mill. kr) (avslutta serie) 1997K4-2009K2',
#   'description': '',
#   'updated': '2009-09-14T08:00:00Z',
#   'firstPeriod': '1997K4',
#   'lastPeriod': '2009K2',
#   'category': 'public',
#   'variableNames': ['selskapstype', 'sektor', 'statistikkvariabel', 'kvartal'],
#   'links': [{'rel': 'self',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04087?lang=no'},
#    {'rel': 'metadata',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04087/metadata?lang=no'},
#    {'rel': 'data',
#     'hreflang': 'no',
#     'href': 'https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/04087/data?lang=no'}]},
#  ...]

# %%
# Transform data
tableIds = []
for item in data: 
    new_item = {
        "tableID": item["id"],
    }
    tableIds.append(new_item)
tableIds[0:5]
# Out:
# [{'tableID': '13760'},
#  {'tableID': '07458'},
#  {'tableID': '13618'},
#  {'tableID': '13619'},
#  {'tableID': '05110'}]

# %% [markdown]
# Hent metadata

# %%
import requests


def hent_meta_data(id):
    try:
        url = f"https://data.qa.ssb.no/pxapi2-beta/api/v2/tables/{id}/metadata"
        respons = requests.get(url)

        if respons.status_code == 200:
            data = respons.json()
            data.pop("contacts", None)
            data.pop("licence", None)
            data.pop("links", None)
            return data, None  # Returnerer data og None for feil
        else:
            return None, f"Feil i forespørsel: Statuskode {respons.status_code}"

    except requests.exceptions.RequestException as e:
        return None, str(e)

# ID for spesifikk tabell
tabell_id = "13760"

# Kaller funksjonen med den spesifikke ID-en og skriver ut resultatet
result = hent_meta_data(tabell_id)
print(result)
# Out:
# ({'language': 'no', 'id': '13760', 'label': '13760: Arbeidsstyrken, sysselsatte, arbeidsledige  og utførte ukeverk for personer 15-74 år, PxcMetaTitleBy kjønn, alder, type justering, statistikkvariabel PxcMetaTitleAnd måned', 'aggregationAllowed': False, 'officalStatistics': True, 'subjectCode': 'al', 'subjectLabel': 'Arbeid og lønn', 'source': 'Statistisk sentralbyrå', 'updated': '2023-04-26T06:00:00Z', 'notes': [{'mandatory': False, 'text': 'Fra og med 24. november 2022 erstatter tabell 13760 tabell 13332 i månedspubliseringene av AKU-tall. Tabell 13760 er bruddjustert og inneholder også tremåneders glidende gjennomsnitt av sesongjusterte månedstall, altså som tabell 13332. Det som er nytt er for det første at den nye tabellen også inneholder sesongjusterte månedstall, altså tallene som danner grunnlaget for de tremåneders glidende gjennomsnittene. For det andre inneholder den trendtall, som representerer den langsiktige tendensen. Trendtallene er glattere enn den sesongjusterte serien, som har nokså høy volatilitet. For det tredje inneholder den nye tabellen månedstall som ikke er sesongjustert. Ettersom det er høy volatilitet i både månedstallene som er sesongjustert og ikke, er det trendtallene og de tremåneders glidende gjennomsnittene av sesongjusterte månedstall vi anbefaler å bruke. De to andre seriene offentliggjør vi hovedsakelig av hensyn til ekspertbrukere av statistikken.\n<br><br>\nTallene er bruddjustert grunnet et brudd mellom 2020 og 2021. Tallene før 2021 er justert til nivået etter bruddet. Utførte ukeverk er ikke bruddjustert grunnet problemer med å skille eventuell effekt av koronakrisen fra eventuell effekt av omleggingen av AKU. Tabellen inneholder ikke befolkningstall for årene 2006-2008, og følgelig heller ikke tall for sysselsatte eller arbeidsstyrken i prosent av befolkningen for de årene. Se Om statistikken for mer informasjon.'}], 'variables': [{'id': 'Kjonn', 'label': 'kjønn', 'type': 'RegularVariable', 'elimination': True, 'values': [{'code': '0', 'label': 'Begge kjønn'}, {'code': '1', 'label': 'Menn'}, {'code': '2', 'label': 'Kvinner'}]}, {'id': 'Alder', 'label': 'alder', 'type': 'RegularVariable', 'elimination': True, 'values': [{'code': '15-74', 'label': '15-74 år'}, {'code': '15-24', 'label': '15-24 år'}, {'code': '25-74', 'label': '25-74 år'}]}, {'id': 'Justering', 'label': 'type justering', 'type': 'RegularVariable', 'elimination': False, 'values': [{'code': 'T', 'label': 'Trend'}, {'code': '3MGG', 'label': 'Sesongjustert, 3-måneders glidende gjennomsnitt'}, {'code': 'S', 'label': 'Sesongjustert'}, {'code': 'IS', 'label': 'Ikke sesongjustert'}]}, {'id': 'ContentsCode', 'label': 'statistikkvariabel', 'type': 'ContentsVariable', 'values': [{'baseperiod': '', 'adjustment': 'WorkAndSes', 'measuringType': 'Average', 'preferedNumberOfDecimals': 0, 'priceType': 'Undefined', 'unit': '1000 personer', 'refrencePeriod': 'Måneden', 'code': 'Arbeidsstyrken', 'label': 'Arbeidsstyrken (1000 personer)'}, {'baseperiod': '', 'adjustment': 'None', 'measuringType': 'Average', 'preferedNumberOfDecimals': 0, 'priceType': 'Undefined', 'unit': '1000 personer', 'refrencePeriod': 'Måneden', 'code': 'Sysselsatte', 'label': 'Sysselsatte (1000 personer)'}, {'baseperiod': '', 'adjustment': 'WorkAndSes', 'measuringType': 'Average', 'preferedNumberOfDecimals': 0, 'priceType': 'Undefined', 'unit': '1000 ukeverk', 'refrencePeriod': 'Måneden', 'code': 'Ukeverk', 'label': 'Utførte ukeverk (1000 ukeverk) à 37,5 timer'}, {'baseperiod': '', 'adjustment': 'WorkAndSes', 'measuringType': 'Average', 'preferedNumberOfDecimals': 0, 'priceType': 'Undefined', 'unit': '1000 personer', 'refrencePeriod': 'Måneden', 'code': 'Arbeidsledige', 'label': 'Arbeidsledige (1000 personer)'}, {'baseperiod': '', 'adjustment': 'WorkAndSes', 'measuringType': 'Average', 'preferedNumberOfDecimals': 1, 'priceType': 'Undefined', 'unit': 'prosent', 'refrencePeriod': 'Måneden', 'code': 'ArbStyrkProsBefolkn', 'label': 'Arbeidsstyrken i prosent av befolkningen ...

# %%
import yaml

# Writing to a YAML file
with open('metaData.yaml', 'w') as file:
    yaml.dump(result, file, allow_unicode=True)

print("Data saved to data.yaml")
# Out:
# Data saved to data.yaml

# %%
# import time
# import yaml

# # Samle all metadata
# all_metadata = []

# for item in tableIds:
#     metadata = hent_meta_data(item["tableID"])
#     if isinstance(metadata, dict):  # Sjekk om responsen er en dictionary
#         all_metadata.append(metadata)
#     time.sleep(3) 

# # Skrive all samlet metadata til en YAML-fil
# with open('all_metadata.yaml', 'w') as file:
#     yaml.dump(all_metadata, file, allow_unicode=True)

# print("All metadata saved to all_metadata.yaml")

# %%
import time
import yaml

# Last inn eksisterende data fra YAML-fil
try:
    with open('all_metadata.yaml', 'r') as file:
        all_metadata = yaml.safe_load(file) or []
except FileNotFoundError:
    all_metadata = []

# Samle all metadata og logg suksessfulle IDs
suksessfulle_ids = []
for item in tableIds:
    metadata, error = hent_meta_data(item["tableID"])
    if metadata:
        all_metadata.append(metadata)
        suksessfulle_ids.append(item["tableID"])
    else:
        print(f"Feil ved henting av data for ID {item['tableID']}: {error}")
    time.sleep(2)  # Øk ventetiden for å redusere risikoen for rate limiting


# Skriv oppdatert metadata til YAML-fil
with open('all_metadata.yaml', 'w') as file:
    yaml.dump(all_metadata, file, allow_unicode=True)

# Lagre suksessfulle IDs til en egen fil for fremtidig referanse
with open('suksessfulle_ids.yaml', 'w') as file:
    yaml.dump(suksessfulle_ids, file, allow_unicode=True)
# Out:
# Feil ved henting av data for ID 07118: Feil i forespørsel: Statuskode 404
# Feil ved henting av data for ID 05431: Feil i forespørsel: Statuskode 404
# Feil ved henting av data for ID 05432: Feil i forespørsel: Statuskode 404
# Feil ved henting av data for ID 06047: Feil i forespørsel: Statuskode 404
# Feil ved henting av data for ID 05433: Feil i forespørsel: Statuskode 404
# Feil ved henting av data for ID 06214: Feil i forespørsel: Statuskode 404
# Feil ved henting av data for ID 06213: Feil i forespørsel: Statuskode 404
# Feil ved henting av data for ID 04472: Feil i forespørsel: Statuskode 404
# Feil ved henting av data for ID 08570: Feil i forespørsel: Statuskode 404
# Feil ved henting av data for ID 04187: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Feil ved henting av data for ID 07334: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Feil ved henting av data for ID 06542: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Feil ved henting av data for ID 11860: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Feil ved henting av data for ID 12376: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Feil ved henting av data for ID 10525: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Feil ved henting av data for ID 06706: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
